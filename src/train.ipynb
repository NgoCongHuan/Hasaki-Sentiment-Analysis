# %%
import pandas as pd

# %%
df = pd.read_csv('../data/clean/hasaki_products_cleaned.csv')

df.head(5)
# Out:
#                                             Liên kết  \
# 0  https://hasaki.vn/san-pham/dung-dich-ve-sinh-p...
# 1  https://hasaki.vn/san-pham/dung-dich-ve-sinh-p...
# 2  https://hasaki.vn/san-pham/bang-ve-sinh-diana-...
# 3  https://hasaki.vn/san-pham/dung-dich-ve-sinh-p...
# 4  https://hasaki.vn/san-pham/dung-dich-ve-sinh-p...
#
#                                         Ảnh sản phẩm  Mã sản phẩm  \
# 0  https://media.hcdn.vn/catalog/product/f/a/face...    422205453
# 1  https://media.hcdn.vn/catalog/product/p/r/prom...    301500006
# 2  https://media.hcdn.vn/catalog/product/p/r/prom...    422206864
# 3  https://media.hcdn.vn/catalog/product/f/a/face...    422205455
# 4  https://media.hcdn.vn/catalog/product/p/r/prom...    301500004
#
#                                         Tên sản phẩm  Mã danh mục  \
# 0  Dung Dịch Vệ Sinh Phụ Nữ Femfresh Cao Cấp Hằng...         1901
# 1  Dung Dịch Vệ Sinh Phụ Nữ Lactacyd Ngăn Mùi 24H...         1901
# ...

# %%
#!/usr/bin/python
# -*- coding: utf-8 -*-
import logging

from vncorenlp import VnCoreNLP


def simple_usage():
    # Uncomment this line for debugging
    # logging.basicConfig(level=logging.DEBUG)

    vncorenlp_file = r'../absolute/path/to/vncorenlp/VnCoreNLP-1.2.jar'

    sentences = 'Mùi hương của cây son này rất thơm, tuy nhiên độ lì thì hơi kém'

    # In this way, you have to close the server manually by calling close function
    vncorenlp = VnCoreNLP(vncorenlp_file)

    print('Tokenizing:', vncorenlp.tokenize(sentences))
    print('POS Tagging:', vncorenlp.pos_tag(sentences))
    print('Named-Entity Recognizing:', vncorenlp.ner(sentences))
    print('Dependency Parsing:', vncorenlp.dep_parse(sentences))
    print('Annotating:', vncorenlp.annotate(sentences))
    print('Language:', vncorenlp.detect_language(sentences))

    # Do not forget to close the server
    vncorenlp.close()

if __name__ == '__main__':
    simple_usage()
# Out:
# Tokenizing: [['Mùi', 'hương', 'của', 'cây_son', 'này', 'rất', 'thơm', ',', 'tuy_nhiên', 'độ', 'lì', 'thì', 'hơi', 'kém']]
# POS Tagging: [[('Mùi', 'N'), ('hương', 'N'), ('của', 'E'), ('cây_son', 'N'), ('này', 'P'), ('rất', 'R'), ('thơm', 'A'), (',', 'CH'), ('tuy_nhiên', 'C'), ('độ', 'N'), ('lì', 'A'), ('thì', 'C'), ('hơi', 'R'), ('kém', 'A')]]
# Named-Entity Recognizing: [[('Mùi', 'O'), ('hương', 'O'), ('của', 'O'), ('cây_son', 'O'), ('này', 'O'), ('rất', 'O'), ('thơm', 'O'), (',', 'O'), ('tuy_nhiên', 'O'), ('độ', 'O'), ('lì', 'O'), ('thì', 'O'), ('hơi', 'O'), ('kém', 'O')]]
# Dependency Parsing: [[('sub', 7, 1), ('nmod', 1, 2), ('nmod', 1, 3), ('pob', 3, 4), ('det', 4, 5), ('amod', 7, 6), ('root', 0, 7), ('punct', 7, 8), ('dep', 7, 9), ('dep', 7, 10), ('nmod', 10, 11), ('dep', 14, 12), ('amod', 14, 13), ('nmod', 10, 14)]]
# ...

# %%
from deep_translator import GoogleTranslator

chatgpt = GoogleTranslator(source='en', target='vi')

chatgpt.translate('I use this with the Nudestix “Citrus Clean Balm & Make-Up Melt“ to double cleanse and it has completely changed my skin (for the better). The make-up melt is oil based and removes all of your makeup super easily. I follow-up with this water based cleanser, and I also use this just by itself when I’m not wearing make-up. It leaves the skin gently cleansed, but without stripping the skin. 10/10 recommend combining with the make-up melt. It is perfection!')
# Out:
# 'Tôi sử dụng sản phẩm này với Nudestix “Citrus Clean Balm & Make-Up Melt“ để làm sạch kép và nó đã thay đổi hoàn toàn làn da của tôi (theo hướng tốt hơn). Make-up melt có gốc dầu và loại bỏ tất cả lớp trang điểm của bạn cực kỳ dễ dàng. Tôi sử dụng tiếp sản phẩm tẩy trang gốc nước này và tôi cũng chỉ sử dụng sản phẩm này khi không trang điểm. Nó giúp làm sạch da nhẹ nhàng nhưng không làm khô da. 10/10 khuyên bạn nên kết hợp với make-up melt. Thật hoàn hảo!'
